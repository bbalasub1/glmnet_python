# %%
import cvglmnet
import numpy as np

# %%
X = np.random.rand(50,3)
y = np.random.rand(50)

# %%
fit1 = cvglmnet.cvglmnet(x=X,y=y,nfolds=20)
# Out:
# Option grouped=false enforced in cv.glmnet, since < 3 observations per fold

# %%
from cvglmnetPlot import cvglmnetPlot

# %%
cvglmnetPlot(fit1)
